# %%
# %pip install azure-ai-inference
# Out:
# Requirement already satisfied: azure-ai-inference in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (1.0.0b3)
# Requirement already satisfied: isodate>=0.6.1 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from azure-ai-inference) (0.6.1)
# Requirement already satisfied: azure-core>=1.30.0 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from azure-ai-inference) (1.30.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from azure-ai-inference) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-inference) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/waqasjaved02/dev/azureai-samples/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage
from azure.ai.inference.models import UserMessage
from azure.core.credentials import AzureKeyCredential


from azure.ai.inference.models import SystemMessage, UserMessage, TextContentItem, ImageContentItem, ImageUrl, ImageDetailLevel

        

client = ChatCompletionsClient( 
   endpoint="https://models.inference.ai.azure.com", 
   credential=AzureKeyCredential(""), 
) 

response = client.complete( 
       messages=[ 
           UserMessage( 
               content=[ 
                   TextContentItem(text="What do you see in these images?"), 
                   ImageContentItem(
                    image_url=
                    ImageUrl.load(
                        image_file="Tom-Cruise-2013.jpg", 
                        image_format="png", 
                        detail=ImageDetailLevel.HIGH, 
                       ), 
                   ), 
                   ImageContentItem( 
                       image_url=
                       ImageUrl( 
                            url="https://raw.githubusercontent.com/Azure/azure-sdk-for-python/main/sdk/ai/azure-ai-inference/samples/sample1.png", 
                           detail=ImageDetailLevel.HIGH, 
                       ),
                   ), 
               ], 
           ), 
       ],
        model="gpt-4o",
        temperature=1,
        max_tokens=4096,
        top_p=1
   ) 

print(response.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 23
#       7 from azure.ai.inference.models import SystemMessage, UserMessage, TextContentItem, ImageContentItem, ImageUrl, ImageDetailLevel
#      11 client = ChatCompletionsClient(
#      12    endpoint="https://models.inference.ai.azure.com",
#      13    credential=AzureKeyCredential("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"),
#      14 )
#      16 response = client.complete(
#      17        messages=[
#      18            UserMessage(
#      19                content=[
#      20                    TextContentItem(text="What do you see in these images?"),
#      21                    ImageContentItem(
#      22                     image_url=
# ---> 23                     ImageUrl.load(
#      24                         image_file="sample1.png",
#      25                         image_format="png",
#      26                         detail=ImageDetailLevel.HIGH,
#      27                        ),
#      28                    ),
#      29                    ImageContentItem(
#      30                        image_url=
#      31                        ImageUrl(
#      32                             url="https://raw.githubusercontent.com/Azure/azure-sdk-for-python/main/sdk/ai/azure-ai-inference/samples/sample1.png",
#      33                            detail=ImageDetailLevel.HIGH,
#      34                        ),
#      35                    ),
#      36                ],
#      37            ),
#      38        ],
#      39         model="gpt-4o",
#      40         temperature=1,
#      41         max_tokens=4096,
#      42         top_p=1
#      43    )
#      45 print(response.choices[0].message)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/ai/inference/models/_patch.py:52, in ImageUrl.load(cls, image_file, image_format, detail)
#      32 @classmethod
#      33 def load(
#      34     cls, *, image_file: str, image_format: str, detail: Optional[Union[str, "_models.ImageDetailLevel"]] = None
#      35 ) -> Self:
#      36     """
#      37     Create an ImageUrl object from a local image file. The method reads the image
#      38     file and encodes it as a base64 string, which together with the image format
#    (...)
#      50     :raises FileNotFoundError: when the image file could not be opened.
#      51     """
# ---> 52     with open(image_file, "rb") as f:
#      53         image_data = base64.b64encode(f.read()).decode("utf-8")
#      54     url = f"data:image/{image_format};base64,{image_data}"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample1.png'

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage
from azure.ai.inference.models import UserMessage
from azure.core.credentials import AzureKeyCredential


from azure.ai.inference.models import SystemMessage, UserMessage, TextContentItem, ImageContentItem, ImageUrl, ImageDetailLevel

        

client = ChatCompletionsClient(
    endpoint="https://models.inference.ai.azure.com",
    credential=AzureKeyCredential(""),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are an AI assistant that describes images in details."),
        UserMessage(
            content=[
                TextContentItem(text="How many images are these?"),
                ImageContentItem(
                    image_url=ImageUrl(
                        url="https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg",
                        detail=ImageDetailLevel.HIGH,
                    ),
                ),
                ImageContentItem(
                    image_url=ImageUrl(
                        url="https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg",
                        detail=ImageDetailLevel.HIGH,
                    ),
                ),
            ],
        ),
    ],
    model="gpt-4o",
    temperature=1,
    max_tokens=4096,
    top_p=1
)


print(response.choices[0].message.content)
# Out:
# The image depicts a person with their face blurred. The individual has short, brown hair that appears to be styled neatly. They are wearing a dark-colored, possibly navy blue, crew-neck shirt. The background appears to be dark, possibly indicating an indoor setting with minimal lighting. Since the face is blurred, no further specific details about the individual's facial features can be provided.

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage
from azure.ai.inference.models import UserMessage
from azure.core.credentials import AzureKeyCredential


from azure.ai.inference.models import SystemMessage, UserMessage, AssistantMessage, TextContentItem, ImageContentItem, ImageUrl, ImageDetailLevel


client = ChatCompletionsClient(
    endpoint="https://models.inference.ai.azure.com",
    credential=AzureKeyCredential(""),
)

response = client.complete(
        messages=[
            SystemMessage(content="You are an AI assistant that describes images in details."),
            UserMessage(
                content=[
                    TextContentItem(text="How many images are these?"),
                    ImageContentItem(
                    image_url=
                    ImageUrl.load(
                        image_file="sample1.png", 
                        image_format="png", 
                        detail=ImageDetailLevel.HIGH, 
                       ), 
                   ), 
                   ImageContentItem(
                        image_url=ImageUrl(
                            url="https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg",
                            detail=ImageDetailLevel.HIGH,
                        ),
                    ),
                ],
            )
        ],
        model="gpt-4o",
        temperature=1,
        max_tokens=4096,
        top_p=1
    )

print(response.choices[0].message.content)
# Out:
# There are two images.

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import ChatRequestMessage
from azure.ai.inference.models import UserMessage
from azure.core.credentials import AzureKeyCredential
import base64 
from pathlib import Path


from azure.ai.inference.models import SystemMessage, UserMessage, TextContentItem, ImageContentItem, ImageUrl, ImageDetailLevel

image_file_path = "ImageTaggingAssistant.jpg"

# Encode the image in base64
with Path(image_file_path).open("rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")


sys_message = "Generate a list of descriptive tags for the following image. Analyze the image carefully and produce tags that accurately represent the image. Ensure the tags are relevant."
user_prompt = "How many images are there?"

client = ChatCompletionsClient(
    endpoint="https://models.inference.ai.azure.com",
    credential=AzureKeyCredential(""),
)

response = client.complete(
        messages = [
            {"role": "system", "content": [{"type": "text", "text": sys_message}]},
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": user_prompt},
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{encoded_image}"}},
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{encoded_image}"}},
                ],
            },
        ],
        model="gpt-4o",
        temperature=1,
        max_tokens=4096,
        top_p=1
    )

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 image_file_path = "ImageTaggingAssistant.jpg"
#      13 # Encode the image in base64
# ---> 14 with Path(image_file_path).open("rb") as image_file:
#      15     encoded_image = base64.b64encode(image_file.read()).decode("utf-8")
#      18 sys_message = "Generate a list of descriptive tags for the following image. Analyze the image carefully and produce tags that accurately represent the image. Ensure the tags are relevant."
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ImageTaggingAssistant.jpg'

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.core.credentials import AzureKeyCredential
import base64 
from pathlib import Path


# image_file_path = "ImageTaggingAssistant.jpg"

# # Encode the image in base64
# with Path(image_file_path).open("rb") as image_file:
#     encoded_image = base64.b64encode(image_file.read()).decode("utf-8")


sys_message = "Analyze the image carefully and produce description that accurately represent the image."

client = ChatCompletionsClient(
    endpoint="https://models.inference.ai.azure.com",
    credential=AzureKeyCredential(""),
)

response = client.complete(
        messages = [
            {"role": "system", "content": [{"type": "text", "text": sys_message}]},
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": "Do you know if this "},
                    {"type": "image_url", "image_url": {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
                    {"type": "text", "text": " is same as this "},
                    {"type": "image_url", "image_url": {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
                    {"type": "text", "text": " ."},
                ],
            },
        ],
        model="gpt-4o",
        temperature=1,
        max_tokens=4096,
        top_p=1
    )

print(response.choices[0].message.content)
# Out:
# The two images are identical based on the unblurred parts visible.

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage
from azure.ai.inference.models import UserMessage
from azure.core.credentials import AzureKeyCredential
import base64 
from pathlib import Path


from azure.ai.inference.models import SystemMessage, UserMessage, TextContentItem, ImageContentItem, ImageUrl, ImageDetailLevel

image_file_path = "math_problem_solveit.png"

# Encode the image in base64
with Path(image_file_path).open("rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")


client = ChatCompletionsClient(
    endpoint="https://models.inference.ai.azure.com",
    credential=AzureKeyCredential(""),
)

response = client.complete(
        messages = [
            {
                "role": "user",
                "content": [
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{encoded_image}"}},
                ],
            },
        ],
        model="gpt-4o",
        temperature=1,
        max_tokens=4096,
        top_p=1
    )

print(response.choices[0].message)
# Out:
# {'content': 'To solve the expression \\(6 \\div 2(1+2)\\), follow the order of operations (PEMDAS/BODMAS: Parentheses/Brackets, Exponents/Orders, Multiplication and Division [from left to right], Addition and Subtraction [from left to right]).\n\n1. **Parentheses/Brackets first**: \\(1 + 2 = 3\\).\n\n   The expression becomes \\(6 \\div 2(3)\\).\n\n2. **Handle Multiplication and Division from left to right**:\n\n   First, \\(6 \\div 2 = 3\\).\n\n   Then, \\(3 \\times 3 = 9\\).\n\nSo, the answer is 9.', 'role': 'assistant'}

# %% [markdown]
# ## To generate image from text.

# %%
import os
from openai import AzureOpenAI
import json

client = AzureOpenAI(
    api_version="2024-05-01-preview",
    azure_endpoint="https://aoai-hanchi-swe-central.openai.azure.com/",
    api_key="",
)

result = client.images.generate(
    model="dall-e-3", # the name of your DALL-E 3 deployment
    prompt="Create an image of the astronaut in desert. ",
    n=1,
    size="1024x1024"
)

print(result.data[0].url)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[20], line 11
#       3 import json
#       5 client = AzureOpenAI(
#       6     api_version="2024-05-01-preview",
#       7     azure_endpoint="https://aoai-hanchi-swe-central.openai.azure.com/",
#       8     api_key="6276eaeddcd644a786aa18eeca8b2f22",
#       9 )
# ---> 11 result = client.images.generate(
#      12     model="dall-e-3", # the name of your DALL-E 3 deployment
#      13     prompt="Create an image of the astronaut in desert. ",
#      14     n=1,
#      15     size="1024x1024"
#      16 )
#      18 print(result.data[0].url)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/resources/images.py:254, in Images.generate(self, prompt, model, n, quality, response_format, size, style, user, extra_headers, extra_query, extra_body, timeout)
#     195 def generate(
#     196     self,
#     197     *,
#    (...)
#     211     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     212 ) -> ImagesResponse:
#     213     """
#     214     Creates an image given a prompt.
#     215
#    (...)
#     252       timeout: Override the client-level default timeout for this request, in seconds
#     253     """
# --> 254     return self._post(
#     255         "/images/generations",
#     256         body=maybe_transform(
#     257             {
#     258                 "prompt": prompt,
#     259                 "model": model,
#     260                 "n": n,
#     261                 "quality": quality,
#     262                 "response_format": response_format,
#     263                 "size": size,
#     264                 "style": style,
#     265                 "user": user,
#     266             },
#     267             image_generate_params.ImageGenerateParams,
#     268         ),
#     269         options=make_request_options(
#     270             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     271         ),
#     272         cast_to=ImagesResponse,
#     273     )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# InternalServerError: Error code: 500 - {'statusCode': 500, 'message': 'Internal server error', 'activityId': '71f91785-5476-4557-b9ad-1d1bfea0efb2'}

# %% [markdown]
# ## Using OPEN AI

# %%
from openai import OpenAI 
import os
from pathlib import Path
import base64 

MODEL="gpt-4o"
client = OpenAI(
    api_key="")

image_file_path = "Tom-Cruise-2013.jpg"

# Encode the image in base64
with Path(image_file_path).open("rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")

sys_message = "You are an AI assistant that describes images in details"

completion = client.chat.completions.create(
  model=MODEL,
  messages= [
                {
                    "role": "system", 
                    "content": [
                        {"type": "text", "text": sys_message}
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Can you describe this image?"},
                        {"type": "image_url", "image_url": {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
                    ],
                },
            ],
)

print("Assistant1: " + completion.choices[0].message.content)

completion = client.chat.completions.create(
  model=MODEL,
  messages= [
                {
                    "role": "system", 
                    "content": [
                        {"type": "text", "text": sys_message}
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Can you describe this image "},
                        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{encoded_image}"}},
                    ],
                },
            ],
)

print("Assistant2: " + completion.choices[0].message.content)

completion = client.chat.completions.create(
  model=MODEL,
  messages= [
                {
                    "role": "system", 
                    "content": [
                        {"type": "text", "text": sys_message}
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "What do you see in this image "},
                    ],
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{encoded_image}"}},
                    ],
                }
            ],
)

print("Assistant3: " + completion.choices[0].message.content)
# Out:
# Assistant1: The image shows a close-up of a man smiling. He has short, brown hair that is neatly groomed, and is wearing a dark grey sweatshirt. The background is dark, which makes the man the primary focus of the image. The lighting highlights his facial features, such as his prominent eyebrows and clear skin.
# Assistant2: The image features a close-up shot of a man with a cheerful smile on his face. He has short, brown hair and is wearing a dark-colored shirt. The background appears to be plain and dark, putting more focus on the man's face. The lighting is even, highlighting his facial features clearly.
# Assistant3: The image shows a man with short, brown hair and a light complexion. He is smiling and looking directly at the camera. The man is wearing a dark-colored shirt, and the background is out of focus but appears to be a dark setting with a lighter horizontal stripe at the top.

# %% [markdown]
# ## This is using [Image] link

# %%
from openai import OpenAI 
import os
from pathlib import Path
import base64 

MODEL="gpt-4o"
client = OpenAI(
    api_key="")

image_file_path = "Tom-Cruise-2013.jpg"

# Encode the image in base64
with Path(image_file_path).open("rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")


sys_message = "You are an AI assistant that describes images in details"

completion = client.chat.completions.create(
  model=MODEL,
  messages= [
                {
                    "role": "system", 
                    "content": [
                        {"type": "text", "text": sys_message}
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Explain this image "},
                    ],
                },
                {
                    "role": "user",
                    "content": "![Image](https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg)",
                }
            ],
)

print("Assistant1: " + completion.choices[0].message.content)

completion = client.chat.completions.create(
  model=MODEL,
  messages= [
                {
                    "role": "system", 
                    "content": [
                        {"type": "text", "text": sys_message}
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Explain this image "},
                    ],
                },
                {
                    "role": "assistant",
                    "content": "![Image](https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg)",
                }
            ],
)

print("Assistant2: " + completion.choices[0].message.content)
# Out:
# Assistant1: The image is a photograph of Tom Cruise, a well-known American actor and producer. In this image, Tom Cruise is likely attending a public event, such as a red carpet or press conference. He is dressed in formal attire, wearing a sleek, dark-colored, collared jacket over a shirt. His hair is styled in a classic manner, slightly parted and well-groomed.
#
# Tom Cruise is smiling, giving a warm and confident expression which is typical in media appearances. The background of the image is blurred, focusing the attention on Tom Cruise himself. The lighting is even, highlighting his facial features without any harsh shadows. It captures his charismatic presence, a hallmark of his appearances in the public eye.
# Assistant2: The image in question likely shows Tom Cruise, a renowned American actor and producer, attending an event in 2013. In this photo, Tom Cruise may be wearing formal attire, possibly a suit, which is typical of his appearances at premieres or award ceremonies. His hair might be styled neatly, as is often the case during these public appearances, and he could be flashing his signature charismatic smile. The background may include other attendees, event signage, or a crowd, typical of red carpet settings. The lighting and setting likely indicate a bright and glamorous atmosphere consistent with high-profile Hollywood events.

# %%
from openai import OpenAI 
import os
from pathlib import Path
import base64 

MODEL="gpt-4o"
client = OpenAI(
    api_key="")

# image_file_path = "Tom-Cruise-2013.jpg"

# # Encode the image in base64
# with Path(image_file_path).open("rb") as image_file:
#     encoded_image = base64.b64encode(image_file.read()).decode("utf-8")

sys_message = "You are an AI assistant that describes images in details"

completion = client.chat.completions.create(
  model=MODEL,
  messages= [
                {
                    "role": "system", 
                    "content": [
                        {"type": "text", "text": sys_message}
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "image_url", "image_url": {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
                    ],
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Can you describe this pictures?"},
                    ],
                },
                {
                    "role": "assistant",
                    "content": [
                        {"type": "text", "text": "The image shows a person smiling. They have light brown hair and are wearing a dark gray shirt. The background is dark, and the lighting highlights their face, giving a clear view of their expression."},
                    ],
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Can you describe this picture again?"},
                    ],
                },
            ],
)

print("Assistant1: " + completion.choices[0].message.content)


completion = client.chat.completions.create(
  model=MODEL,
  messages= [
                {
                    "role": "system", 
                    "content": [
                        {"type": "text", "text": sys_message}
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Create an image for astronaut"},
                    ],
                },
                {
                    "role": "assistant",
                    "content": [
                        {"type": "image_url", "image_url": {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
                    ],
                },
                
            ],
)

print("Assistant2: " + completion.choices[0].message.content)
# Out:
# Assistant1: The image shows a person with light brown hair, smiling and looking at the camera. They are wearing a dark gray shirt. The background is dark, which makes the person's face and expression stand out. The lighting is focused on the person's face.
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[21], line 57
#      18 completion = client.chat.completions.create(
#      19   model=MODEL,
#      20   messages= [
#    (...)
#      51             ],
#      52 )
#      54 print("Assistant1: " + completion.choices[0].message.content)
# ---> 57 completion = client.chat.completions.create(
#      58   model=MODEL,
#      59   messages= [
#      60                 {
#      61                     "role": "system",
#      62                     "content": [
#      63                         {"type": "text", "text": sys_message}
#      64                     ]
#      65                 },
#      66                 {
#      67                     "role": "user",
#      68                     "content": [
#      69                         {"type": "text", "text": "Create an image for astronaut"},
#      70                     ],
#      71                 },
#      72                 {
#      73                     "role": "assistant",
#      74                     "content": [
#      75                         {"type": "image_url", "image_url": {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
#      76                     ],
#      77                 },
#      78
#      79             ],
#      80 )
#      82 print("Assistant2: " + completion.choices[0].message.content)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:646, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     612 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     613 def create(
#     614     self,
#    (...)
#     644     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     645 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 646     return self._post(
#     647         "/chat/completions",
#     648         body=maybe_transform(
#     649             {
#     650                 "messages": messages,
#     651                 "model": model,
#     652                 "frequency_penalty": frequency_penalty,
#     653                 "function_call": function_call,
#     654                 "functions": functions,
#     655                 "logit_bias": logit_bias,
#     656                 "logprobs": logprobs,
#     657                 "max_tokens": max_tokens,
#     658                 "n": n,
#     659                 "parallel_tool_calls": parallel_tool_calls,
#     660                 "presence_penalty": presence_penalty,
#     661                 "response_format": response_format,
#     662                 "seed": seed,
#     663                 "service_tier": service_tier,
#     664                 "stop": stop,
#     665                 "stream": stream,
#     666                 "stream_options": stream_options,
#     667                 "temperature": temperature,
#     668                 "tool_choice": tool_choice,
#     669                 "tools": tools,
#     670                 "top_logprobs": top_logprobs,
#     671                 "top_p": top_p,
#     672                 "user": user,
#     673             },
#     674             completion_create_params.CompletionCreateParams,
#     675         ),
#     676         options=make_request_options(
#     677             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     678         ),
#     679         cast_to=ChatCompletion,
#     680         stream=stream or False,
#     681         stream_cls=Stream[ChatCompletionChunk],
#     682     )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "Invalid 'messages[2]'. Image URLs are only allowed for messages with role 'user', but this message with role 'assistant' contains an image URL.", 'type': 'invalid_request_error', 'param': 'messages[2]', 'code': 'invalid_value'}}

# %% [markdown]
# Spec Examples

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage
from azure.ai.inference.models import UserMessage
from azure.core.credentials import AzureKeyCredential


from azure.ai.inference.models import SystemMessage, UserMessage, AssistantMessage, TextContentItem, ImageContentItem, ImageUrl, ImageDetailLevel

        

client = ChatCompletionsClient( 
   endpoint="https://models.inference.ai.azure.com", 
   credential=AzureKeyCredential(""), 
) 

image_file_path = "ImageTaggingAssistant.jpg"

# Encode the image in base64
with Path(image_file_path).open("rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")
    

sys_message = "Analyze the image carefully and produce description that accurately represent the image."

response = client.complete( 
       messages = [
            {
                "role": "system", 
                "content": [
                    {"type": "text", "text": sys_message}
                ]
            },
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": "Do you know if this "},
                    {"type": "image_url", "image_url": {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
                    {"type": "text", "text": " is same as this "},
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{encoded_image}"}},
                ],
            },
        ],
        model="gpt-4o",
        temperature=1,
        max_tokens=4096,
        top_p=1 
   ) 

print(response.choices[0].message)
# Out:
# {'content': 'The first image shows a person wearing a dark shirt. The second image is a colorful assortment of fruits and vegetables. These images depict completely different subjects.', 'role': 'assistant'}

# %%
from openai import OpenAI 
import os
from pathlib import Path
import base64 

MODEL="gpt-4o"
client = OpenAI(
    api_key="")

# image_file_path = "Tom-Cruise-2013.jpg"

# # Encode the image in base64
# with Path(image_file_path).open("rb") as image_file:
#     encoded_image = base64.b64encode(image_file.read()).decode("utf-8")

sys_message = "You are an AI assistant who can describe pictures."

completion = client.chat.completions.create(
  model=MODEL,
  messages = [
            {
                "role": "system", 
                "content": [
                    {"type": "text", "text": sys_message}
                ]
            },
            {
                "role": "user",
                "content": [
                    {"type": "image_url", "image_url": 
                    {"url": "https://cdn.britannica.com/68/178268-050-5B4E7FB6/Tom-Cruise-2013.jpg"}},
                ],
            },
        ],
)

print("Assistant1: " + completion.choices[0].message.content)
# Out:
# Assistant1: I'm sorry, I can't identify this person.

# %%
import pandas as pd
import json
from pprint import pprint

# # Define the input and output file paths
# input_file_path = 'evaluate_multimodal_messages.jsonl'
# output_file_path = 'out.jsonl'

# # Read the entire JSON file as a dictionary
# with open(input_file_path, 'r') as file:
#     data = json.load(file)

# # Normalize the nested structure into a flat table
# df = pd.json_normalize(data)

# # Save the flattened structure into a new JSONL file
# df.to_json(output_file_path, orient='records', lines=True)

# print(f"Flattened JSON saved to {output_file_path}")

dd = pd.read_json('out.jsonl', lines=True)

dd
# Out:
#                                             messages
# 0  [{'role': 'system', 'content': [{'type': 'text...
# 1  [{'role': 'system', 'content': [{'type': 'text...
