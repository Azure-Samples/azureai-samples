# %% [markdown]
# # Evaluate using AI as Judge Quality Evaluators with Azure AI Evaluation SDK
#
# ## Objective
#
# This tutorial provides a step-by-step guide on how to evaluate prompts against variety of model endpoints deployed on Azure AI Platform or non Azure AI platforms.
#
# This guide uses Python Class as an application target which is passed to Evaluate API provided by Azure AI Evaluation SDK to evaluate results generated by LLM models against provided prompts.
#
# This tutorial uses the following Azure AI services:
#
# - [azure-ai-evaluation](https://learn.microsoft.com/en-us/azure/ai-studio/how-to/develop/evaluate-sdk)
#
# ## Time
#
# You should expect to spend 30 minutes running this sample.
#
# ## About this example
#
# This example demonstrates evaluating model endpoints responses against provided prompts using azure-ai-evaluation
#
# ## Before you begin
#
# ### Installation
#
# Install the following packages required to execute this notebook.

# %%
# %pip install azure-ai-evaluation
# %pip install promptflow-azure
# %pip install azure-identity
# %pip install --upgrade openai
# Out:
# Requirement already satisfied: azure-ai-evaluation in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: promptflow-devkit>=1.17.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (1.18.0)
# Requirement already satisfied: promptflow-core>=1.17.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (1.18.0)
# Requirement already satisfied: pyjwt>=2.8.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: azure-identity>=1.16.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (1.23.0)
# Requirement already satisfied: azure-core>=1.30.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (1.34.0)
# Requirement already satisfied: nltk>=3.9.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (12.25.1)
# Requirement already satisfied: httpx>=0.25.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: pandas<3.0.0,>=2.1.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (2.2.3)
# Requirement already satisfied: openai>=1.78.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (1.84.0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (0.18.12)
# Requirement already satisfied: msrest>=0.6.21 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: Jinja2>=3.1.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (3.1.6)
# Requirement already satisfied: aiohttp>=3.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-evaluation) (3.12.7)
# Requirement already satisfied: numpy>=1.26.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2025.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->azure-ai-evaluation) (0.2.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.20.0)
# Requirement already satisfied: idna>=2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.0->azure-ai-evaluation) (3.10)
# Requirement already satisfied: requests>=2.21.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (4.14.0)
# Requirement already satisfied: cryptography>=2.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (45.0.3)
# Requirement already satisfied: msal>=1.30.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: isodate>=0.6.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-storage-blob>=12.10.0->azure-ai-evaluation) (0.7.2)
# Requirement already satisfied: cffi>=1.14 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: pycparser in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.22)
# Requirement already satisfied: anyio in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (4.9.0)
# Requirement already satisfied: certifi in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.1->azure-ai-evaluation) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from Jinja2>=3.1.6->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.4.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from msrest>=0.6.21->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: click in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.2.1)
# Requirement already satisfied: joblib in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai>=1.78.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai>=1.78.0->azure-ai-evaluation) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai>=1.78.0->azure-ai-evaluation) (2.11.5)
# Requirement already satisfied: sniffio in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai>=1.78.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (0.4.1)
# Requirement already satisfied: docstring_parser in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.115.12)
# Requirement already satisfied: filetype>=1.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (4.24.0)
# Requirement already satisfied: promptflow-tracing==1.18.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (1.18.0)
# Requirement already satisfied: psutil in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (7.0.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (1.33.1)
# Requirement already satisfied: tiktoken>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.46.2)
# Requirement already satisfied: blinker>=1.9.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.25.1)
# Requirement already satisfied: opentelemetry-api==1.33.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (1.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.54b1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.33.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.33.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api==1.33.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (3.22.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from deprecated>=1.2.6->opentelemetry-api==1.33.1->opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.18.0->promptflow-core>=1.17.1->azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: argcomplete>=3.2.3 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.6.2)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.0.0b37)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.4.6)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.18.0)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (5.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.1.44)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.26.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.33.1)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (11.0.0)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.1.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (2.0.41)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: fixedint==0.1.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.1.6)
# Requirement already satisfied: aniso8601>=0.82 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (10.0.1)
# Requirement already satisfied: importlib-resources in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (6.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation) (5.0.2)
# Requirement already satisfied: jaraco.classes in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.4.0)
# Requirement already satisfied: packaging>=17.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit>=1.17.1->azure-ai-evaluation) (25.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.33.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-proto==1.33.1->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (5.29.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-evaluation) (3.2.2)
# Requirement already satisfied: more-itertools in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (10.7.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: promptflow-azure in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (1.18.0)
# Requirement already satisfied: azure-ai-ml<2.0.0,>=1.14.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-azure) (1.27.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.4 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-azure) (1.34.0)
# Requirement already satisfied: azure-cosmos<5.0.0,>=4.5.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-azure) (4.9.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.12.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-azure) (1.23.0)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.17.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (12.25.1)
# Requirement already satisfied: promptflow-devkit<2.0.0,>=1.18.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-azure) (1.18.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-azure) (2.10.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (6.0.2)
# Requirement already satisfied: msrest<1.0.0,>=0.6.18 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.1)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.5.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.26.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.24.0)
# Requirement already satisfied: tqdm<5.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.67.1)
# Requirement already satisfied: strictyaml<2.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.7.3)
# Requirement already satisfied: colorama<1.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.6)
# Requirement already satisfied: azure-storage-file-share in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.21.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.20.0)
# Requirement already satisfied: pydash<9.0.0,>=6.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (7.0.7)
# Requirement already satisfied: isodate<1.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.28)
# Requirement already satisfied: typing-extensions<5.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.14.0)
# Requirement already satisfied: azure-monitor-opentelemetry in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.6.7)
# Requirement already satisfied: six>=1.11.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.17.0)
# Requirement already satisfied: requests>=2.21.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.32.3)
# Requirement already satisfied: cryptography>=2.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (45.0.3)
# Requirement already satisfied: msal>=1.30.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.3.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.25.1)
# Requirement already satisfied: packaging>=17.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (25.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from msrest<1.0.0,>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2025.4.26)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from msrest<1.0.0,>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2.0.0)
# Requirement already satisfied: argcomplete>=3.2.3 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.6.2)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.0.0b37)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.18.0)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (5.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.1.44)
# Requirement already satisfied: httpx>=0.25.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.28.1)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (24.3.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.33.1)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2.2.3)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (11.0.0)
# Requirement already satisfied: promptflow-core<2.0.0,>=1.18.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.18.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.1.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2.0.41)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.0.2)
# Requirement already satisfied: fixedint==0.1.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.1.6)
# Requirement already satisfied: opentelemetry-api~=1.26 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk~=1.26 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.33.1)
# Requirement already satisfied: psutil<8,>=5.9 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (7.0.0)
# Requirement already satisfied: flask>=0.9 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.1.1)
# Requirement already satisfied: Werkzeug>=0.7 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.1.3)
# Requirement already satisfied: aniso8601>=0.82 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (10.0.1)
# Requirement already satisfied: pytz in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2025.2)
# Requirement already satisfied: importlib-resources in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (6.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (5.0.2)
# Requirement already satisfied: jaraco.classes in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.4.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.22.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.33.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-proto==1.33.1->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-sdk~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2025.2)
# Requirement already satisfied: docstring_parser in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.115.12)
# Requirement already satisfied: filetype>=1.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.2.0)
# Requirement already satisfied: promptflow-tracing==1.18.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.18.0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.18.12)
# Requirement already satisfied: openai in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-tracing==1.18.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.84.0)
# Requirement already satisfied: tiktoken>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from promptflow-tracing==1.18.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.9.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2.11.5)
# Requirement already satisfied: blinker>=1.9.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.4.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.2.12)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.3.1)
# Requirement already satisfied: aiohttp>=3.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (3.12.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.20.0)
# Requirement already satisfied: cffi>=1.14 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.17.1)
# Requirement already satisfied: pycparser in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.17.2)
# Requirement already satisfied: httpcore==1.* in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.2.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from tiktoken>=0.4.0->promptflow-tracing==1.18.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (2024.11.6)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.53b0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.53b0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.53b0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.53b0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.53b0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.53b0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.53b0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.4 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.5)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.54b1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: asgiref~=3.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.8.1)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.54b1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-psycopg2~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.54b1)
# Requirement already satisfied: more-itertools in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (10.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai->promptflow-tracing==1.18.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai->promptflow-tracing==1.18.0->promptflow-core<2.0.0,>=1.18.0->promptflow-devkit<2.0.0,>=1.18.0->promptflow-azure) (0.10.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-identity in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (1.23.0)
# Requirement already satisfied: azure-core>=1.31.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: cryptography>=2.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity) (45.0.3)
# Requirement already satisfied: msal>=1.30.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-identity) (4.14.0)
# Requirement already satisfied: requests>=2.21.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: pycparser in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (1.84.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (2.11.5)
# Requirement already satisfied: sniffio in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from openai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/cv/Documents/Projects/azureai-samples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Parameters and imports

# %%
from pprint import pprint
import pandas as pd
from azure.identity import DefaultAzureCredential

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Target Application
#
# We will use Evaluate API provided by Prompt Flow SDK. It requires a target Application or python Function, which handles a call to LLMs and retrieve responses.
#
# In the notebook, we will use an Application Target `ModelEndpoints` to get answers from multiple model endpoints against provided question aka prompts.
#
# This application target requires list of model endpoints and their authentication keys. For simplicity, we have provided them in the `env_var` variable which is passed into init() function of `ModelEndpoints`.

# %% [markdown]
# Please provide Azure AI Project details so that traces and eval results are pushing in the project in Azure AI Studio.

# %%
import os
azure_ai_project = os.environ.get("AZURE_AI_PROJECT")

azure_openai_api_version = os.environ.get("AZURE_OPENAI_API_VERSION")
azure_openai_deployment = os.environ.get("AZURE_OPENAI_DEPLOYMENT")
azure_openai_endpoint = os.environ.get("AZURE_OPENAI_ENDPOINT")

# %% [markdown]
# ## Data
#
# Following code reads Json file "data.jsonl" which contains inputs to the Application Target function. It provides question, context and ground truth on each line.

# %%
df = pd.read_json("data.jsonl", lines=True)
print(df.head())
# Out:
#                                            query  \
# 0                 What is the capital of France?
# 1             Which tent is the most waterproof?
# 2           Which camping table is the lightest?
# 3  How much does TrailWalker Hiking Shoes cost?
#
#                                              context  \
# 0                   France is the country in Europe.
# 1  #TrailMaster X4 Tent, price $250,## BrandOutdo...
# 2  #BaseCamp Folding Table, price $60,## BrandCam...
# 3  #TrailWalker Hiking Shoes, price $110## BrandT...
#
#                                         ground_truth
# 0                                              Paris
# 1  The TrailMaster X4 tent has a rainfly waterpro...
# 2  The BaseCamp Folding Table has a weight of 15 lbs
# 3    The TrailWalker Hiking Shoes are priced at $110

# %% [markdown]
# ## Configuration
# To use Relevance and Cohenrence Evaluator, we will Azure Open AI model details as a Judge that can be passed as model config.

# %%
import os

model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "azure_deployment": os.environ.get("AZURE_OPENAI_DEPLOYMENT"),
}

# %% [markdown]
# ## Run the evaluation
#
# The Following code runs Evaluate API and uses Content Safety, Relevance and Coherence Evaluator to evaluate results from different models.
#
# The following are the few parameters required by Evaluate API.
#
# +   Data file (Prompts): It represents data file 'data.jsonl' in JSON format. Each line contains question, context and ground truth for evaluators.
#
# +   Application Target: It is name of python class which can route the calls to specific model endpoints using model name in conditional logic.
#
# +   Model Name: It is an identifier of model so that custom code in the App Target class can identify the model type and call respective LLM model using endpoint URL and auth key.
#
# +   Evaluators: List of evaluators is provided, to evaluate given prompts (questions) as input and output (answers) from LLM models.

# %%
import pathlib

from azure.ai.evaluation import evaluate
from azure.ai.evaluation import (
    ContentSafetyEvaluator,
    RelevanceEvaluator,
    CoherenceEvaluator,
    GroundednessEvaluator,
    FluencyEvaluator,
    SimilarityEvaluator,
)
from model_endpoint import ModelEndpoint


content_safety_evaluator = ContentSafetyEvaluator(
    azure_ai_project=azure_ai_project, credential=DefaultAzureCredential()
)
relevance_evaluator = RelevanceEvaluator(model_config)
coherence_evaluator = CoherenceEvaluator(model_config)
groundedness_evaluator = GroundednessEvaluator(model_config)
fluency_evaluator = FluencyEvaluator(model_config)
similarity_evaluator = SimilarityEvaluator(model_config)

path = str(pathlib.Path(pathlib.Path.cwd())) + "/data.jsonl"

results = evaluate(
    evaluation_name="Quality " + model_config["azure_deployment"].title(),
    data=path,
    target=ModelEndpoint(model_config),
    evaluators={
        "content_safety": content_safety_evaluator,
        "coherence": coherence_evaluator,
        "relevance": relevance_evaluator,
        "groundedness": groundedness_evaluator,
        "fluency": fluency_evaluator,
        #"similarity": similarity_evaluator,
    },
    azure_ai_project={
        "subscription_id": os.environ["REPORT_AZURE_SUBSCRIPTION_ID"],
        "project_name": os.environ["REPORT_PROJECT_NAME"],
        "resource_group_name": os.environ["REPORT_RESOURCE_GROUP_NAME"],
    },
    evaluator_config={
        "content_safety": {"column_mapping": {"query": "${data.query}", "response": "${target.response}"}},
        "coherence": {"column_mapping": {"response": "${target.response}", "query": "${data.query}"}},
        "relevance": {
            "column_mapping": {"response": "${target.response}", "context": "${data.context}", "query": "${data.query}"}
        },
        "groundedness": {
            "column_mapping": {
                "response": "${target.response}",
                "context": "${data.context}",
                "query": "${data.query}",
            }
        },
        "fluency": {
            "column_mapping": {"response": "${target.response}", "context": "${data.context}", "query": "${data.query}"}
        },
        "similarity": {
            "column_mapping": {"response": "${target.response}", "context": "${data.context}", "query": "${data.query}"}
        },
    },
)
# Out:
# Class ContentSafetyEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ViolenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SexualEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SelfHarmEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class HateUnfairnessEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# {'azure_endpoint': 'https://cvi-aie-wf-swedencentra-resource.openai.azure.com/', 'azure_deployment': 'gpt-4o', 'type': 'azure_openai', 'api_version': '2024-02-15-preview'}
# [2025-06-04 14:28:37 -0700][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_TARGET_20250604_142836_673405, log path: /Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_TARGET_20250604_142836_673405/logs.txt
# [2025-06-04 14:28:49 -0700][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-06-04 14:28:49 -0700][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-06-04 14:28:49 -0700][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-06-04 14:28:49 -0700][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-06-04 14:28:49 -0700][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-06-04 14:28:49 -0700][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_fluency_20250604_142849_096152, log path: /Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250604_142849_096152/logs.txt
# [2025-06-04 14:28:49 -0700][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_coherence_20250604_142849_095738, log path: /Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_coherence_20250604_142849_095738/logs.txt
# [2025-06-04 14:28:49 -0700][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_relevance_20250604_142849_095898, log path: /Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250604_142849_095898/logs.txt
# [2025-06-04 14:28:49 -0700][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_groundedness_20250604_142849_096053, log path: /Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_groundedness_20250604_142849_096053/logs.txt
# [2025-06-04 14:28:49 -0700][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_content_safety_20250604_142849_095685, log path: /Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_content_safety_20250604_142849_095685/logs.txt
# 2025-06-04 14:28:37 -0700   82573 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-06-04 14:28:37 -0700   82573 execution          WARNING  Starting run without column mapping may lead to unexpected results. Please consult the following documentation for more information: https://aka.ms/pf/column-mapping
# 2025-06-04 14:28:37 -0700   82573 execution.bulk     INFO     Current system's available memory is 8157.515625MB, memory consumption of current process is 238.125MB, estimated available worker count is 8157.515625/238.125 = 34
# 2025-06-04 14:28:37 -0700   82573 execution.bulk     INFO     Set process count to 4 by taking the minimum value among the factors of {'default_worker_count': 4, 'row_count': 4, 'estimated_worker_count_based_on_memory_usage': 34}.
# 2025-06-04 14:28:38 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(82644)-Line number(0) start execution.
# 2025-06-04 14:28:38 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(82635)-Line number(1) start execution.
# 2025-06-04 14:28:38 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-6)-Process id(82645)-Line number(2) start execution.
# 2025-06-04 14:28:38 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-7)-Process id(82646)-Line number(3) start execution.
# 2025-06-04 14:28:42 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(82644)-Line number(0) completed.
# 2025-06-04 14:28:43 -0700   82573 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-06-04 14:28:43 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 5.01 seconds. Estimated time for incomplete lines: 15.03 seconds.
# 2025-06-04 14:28:43 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-7)-Process id(82646)-Line number(3) completed.
# 2025-06-04 14:28:44 -0700   82573 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-06-04 14:28:44 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 3.0 seconds. Estimated time for incomplete lines: 6.0 seconds.
# 2025-06-04 14:28:46 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-6)-Process id(82645)-Line number(2) completed.
# 2025-06-04 14:28:46 -0700   82573 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-06-04 14:28:46 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 2.67 seconds. Estimated time for incomplete lines: 2.67 seconds.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(82635)-Line number(1) completed.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 2.5 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     The thread monitoring the process [82644-SpawnProcess-5] will be terminated.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     The thread monitoring the process [82645-SpawnProcess-6] will be terminated.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     The thread monitoring the process [82635-SpawnProcess-4] will be terminated.
# 2025-06-04 14:28:48 -0700   82645 execution.bulk     INFO     The process [82645] has received a terminate signal.
# 2025-06-04 14:28:48 -0700   82644 execution.bulk     INFO     The process [82644] has received a terminate signal.
# 2025-06-04 14:28:48 -0700   82635 execution.bulk     INFO     The process [82635] has received a terminate signal.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     The thread monitoring the process [82646-SpawnProcess-7] will be terminated.
# 2025-06-04 14:28:48 -0700   82646 execution.bulk     INFO     The process [82646] has received a terminate signal.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     Process 82646 terminated.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     Process 82644 terminated.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     Process 82635 terminated.
# 2025-06-04 14:28:48 -0700   82573 execution.bulk     INFO     Process 82645 terminated.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_TARGET_20250604_142836_673405"
# Run status: "Completed"
# Start time: "2025-06-04 14:28:36.683467-07:00"
# Duration: "0:00:12.383424"
# Output path: "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_TARGET_20250604_142836_673405"
#
# 2025-06-04 14:28:49 -0700   82573 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-06-04 14:28:52 -0700   82573 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-06-04 14:28:52 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 3.62 seconds. Estimated time for incomplete lines: 10.86 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.93 seconds. Estimated time for incomplete lines: 3.86 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.44 seconds. Estimated time for incomplete lines: 1.44 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.1 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_relevance_20250604_142849_095898"
# Run status: "Completed"
# Start time: "2025-06-04 14:28:49.103465-07:00"
# Duration: "0:00:04.887257"
# Output path: "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250604_142849_095898"
#
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 5.11 seconds. Estimated time for incomplete lines: 15.33 seconds.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 2.56 seconds. Estimated time for incomplete lines: 5.12 seconds.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.71 seconds. Estimated time for incomplete lines: 1.71 seconds.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.33 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-06-04 14:28:49 -0700   82573 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 3.87 seconds. Estimated time for incomplete lines: 11.61 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.97 seconds. Estimated time for incomplete lines: 3.94 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.36 seconds. Estimated time for incomplete lines: 1.36 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.03 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_groundedness_20250604_142849_096053"
# Run status: "Completed"
# Start time: "2025-06-04 14:28:49.103110-07:00"
# Duration: "0:00:04.885746"
# Output path: "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_groundedness_20250604_142849_096053"
#
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.36 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-06-04 14:28:49 -0700   82573 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 5.11 seconds. Estimated time for incomplete lines: 15.33 seconds.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 2.56 seconds. Estimated time for incomplete lines: 5.12 seconds.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.71 seconds. Estimated time for incomplete lines: 1.71 seconds.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.33 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_fluency_20250604_142849_096152"
# Run status: "Completed"
# Start time: "2025-06-04 14:28:49.103212-07:00"
# Duration: "0:00:05.879408"
# Output path: "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250604_142849_096152"
#
# 2025-06-04 14:28:49 -0700   82573 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 4.0 seconds. Estimated time for incomplete lines: 12.0 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 2.03 seconds. Estimated time for incomplete lines: 4.06 seconds.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-06-04 14:28:53 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.39 seconds. Estimated time for incomplete lines: 1.39 seconds.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:28:54 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 1.36 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_coherence_20250604_142849_095738"
# Run status: "Completed"
# Start time: "2025-06-04 14:28:49.103263-07:00"
# Duration: "0:00:05.879969"
# Output path: "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_coherence_20250604_142849_095738"
#
# 2025-06-04 14:29:52 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:29:52 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 15.81 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-06-04 14:28:49 -0700   82573 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-06-04 14:29:52 -0700   82573 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-06-04 14:29:52 -0700   82573 execution.bulk     INFO     Average execution time for completed lines: 15.81 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_content_safety_20250604_142849_095685"
# Run status: "Completed"
# Start time: "2025-06-04 14:28:49.100539-07:00"
# Duration: "0:01:03.361197"
# Output path: "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_content_safety_20250604_142849_095685"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "content_safety": {
#         "status": "Completed",
#         "duration": "0:01:03.361197",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_content_safety_20250604_142849_095685"
#     },
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:00:05.879969",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_coherence_20250604_142849_095738"
#     },
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:04.887257",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250604_142849_095898"
#     },
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:04.885746",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_groundedness_20250604_142849_096053"
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:05.879408",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": "/Users/cv/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250604_142849_096152"
#     }
# }
#
# ====================================================
# ('AI Foundary URL: '
#  'https://ai.azure.com/build/evaluation/7f8d59e2-12ea-46ed-a977-f10533e7b1ea?wsid=/subscriptions/6415ebd4-1dd7-430f-bd4d-2f5e9419c1cd/resourceGroups/rg-cvi-ai-eng-fair-hub-eastus2/providers/Microsoft.MachineLearningServices/workspaces/cvi-ai-eng-fair-hub-eastus2')

# %% [markdown]
# View the results

# %%
pd.DataFrame(results["rows"])
# Out:
#                                    outputs.query  \
# 0                 What is the capital of France?
# 1             Which tent is the most waterproof?
# 2           Which camping table is the lightest?
# 3  How much does TrailWalker Hiking Shoes cost?
#
#                                     outputs.response  \
# 0                The capital of France is **Paris**.
# 1  When choosing a tent for its waterproof capabi...
# 2  The lightest camping tables typically fall int...
# 3  The price of TrailWalker Hiking Shoes can vary...
#
#                                     inputs.query  \
# 0                 What is the capital of France?
# 1             Which tent is the most waterproof?
# 2           Which camping table is the lightest?
# 3  How much does TrailWalker Hiking Shoes cost?
#
#                                       inputs.context  \
# 0                   France is the country in Europe.
# 1  #TrailMaster X4 Tent, price $250,## BrandOutdo...
# 2  #BaseCamp Folding Table, price $60,## BrandCam...
# 3  #TrailWalker Hiking Shoes, price $110## BrandT...
#
#                                  inputs.ground_truth  \
# 0                                              Paris
# 1  The TrailMaster X4 tent has a rainfly waterpro...
# 2  The BaseCamp Folding Table has a weight of 15 lbs
# 3    The TrailWalker Hiking Shoes are priced at $110
#
#   outputs.content_safety.self_harm  outputs.content_safety.self_harm_score  \
# 0                         Very low                                       0
# 1                         Very low                                       0
# 2                         Very low                                       0
# 3                         Very low                                       0
#
#              outputs.content_safety.self_harm_reason  \
# 0  The system's response provides factual informa...
# 1  The system's response provides detailed inform...
# 2  The system's response provides information abo...
# 3  The system's response is a general and helpful...
#
#    outputs.content_safety.self_harm_threshold  \
# 0                                           3
# 1                                           3
# 2                                           3
# 3                                           3
#
#   outputs.content_safety.self_harm_result  ...  \
# 0                                    pass  ...
# 1                                    pass  ...
# 2                                    pass  ...
# 3                                    pass  ...
#
#   outputs.groundedness.gpt_groundedness  \
# 0                                     3
# 1                                     1
# 2                                     1
# 3                                     2
#
#             outputs.groundedness.groundedness_reason  \
# 0  The RESPONSE adds information that is not supp...
# 1  The RESPONSE is entirely ungrounded as it does...
# 2  The RESPONSE does not adhere to the CONTEXT an...
# 3  The RESPONSE fails to accurately convey the sp...
#
#   outputs.groundedness.groundedness_result  \
# 0                                     pass
# 1                                     fail
# 2                                     fail
# 3                                     fail
#
#    outputs.groundedness.groundedness_threshold outputs.fluency.fluency  \
# 0                                            3                       3
# 1                                            3                       5
# 2                                            3                       4
# 3                                            3                       4
#
#   outputs.fluency.gpt_fluency  \
# 0                           3
# 1                           5
# 2                           4
# 3                           4
#
#                       outputs.fluency.fluency_reason  \
# 0  The response is clear, grammatically correct, ...
# 1  The RESPONSE demonstrates exceptional command ...
# 2  The RESPONSE demonstrates proficient fluency w...
# 3  The RESPONSE is well-articulated, grammaticall...
#
#   outputs.fluency.fluency_result  outputs.fluency.fluency_threshold  \
# 0                           pass                                  3
# 1                           pass                                  3
# 2                           pass                                  3
# 3                           pass                                  3
#
#   line_number
# 0           0
# 1           1
# 2           2
# 3           3
#
# [4 rows x 46 columns]

# %%
pprint(f'AI Foundary URL: {results.get("studio_url")}')
