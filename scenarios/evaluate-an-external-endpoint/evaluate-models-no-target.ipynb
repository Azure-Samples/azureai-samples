# %% [markdown]
# # Evaluate External model endpoints
#
# ## Objective
#
# This tutorial provides a step-by-step guide on how to evaluate response from external model endpoints such as Llama deployed on HuggingFace platform.

# %%
# %pip install promptflow-evals
# %pip install promptflow-azure

# %%
import pandas as pd
import os

from pprint import pprint
from pathlib import Path

import json
import requests

# %%
azure_ai_project = {
    "subscription_id": "2d385bf4-0756-4a76-aa95-28bf9ed3b625",
    "resource_group_name": "rg-wjphihub",
    "project_name": "waqasjaved-5368"
}

# %%
# We recommend to push endpoint and url to env and use os.get_env()
env = {
    "tiny_llama" : {
        "endpoint" : "https://api-inference.huggingface.co/models/TinyLlama/TinyLlama-1.1B-Chat-v1.0/v1/chat/completions",
	    "key" : "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",
    },
    "phi3_mini" : {
        "endpoint" : "https://Phi-3-mini-4k-instruct-rqvel.eastus2.models.ai.azure.com/v1/chat/completions",
	    "key" : "J6HAqLPf6jyC0ApRXkXRE0cdSpdINcgm",
    },
    "gpt2" : {
        "endpoint" : "https://api-inference.huggingface.co/models/openai-community/gpt2",
	    "key" : "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",
    },
}

# %%
def call_tiny_llama_endpoint(question: str) -> str:

	endpoint = env["tiny_llama"]["endpoint"]
	key = env["tiny_llama"]["key"]

	headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ key) }

	print(endpoint)
	print(key)
	print(headers)

	def query(payload):
		print(payload)
		response = requests.post(endpoint, headers=headers, json=payload)
		return response.json()
		
	output = query({
		"model": "TinyLlama/TinyLlama-1.1B-Chat-v1.0",
		"messages": [{
			"role": "user", 
			"content": question
			}],
		"max_tokens": 500,
		"stream": False
		})

	answer = output["choices"][0]["message"]["content"]
	return "{ \"question\" : \" " + question + "\" , \"answer\" : \" " + answer + " \"}"

def call_phi3_mini_endpoint(question: str) -> str:

	endpoint = env["phi3_mini"]["endpoint"]
	key = env["phi3_mini"]["key"]

	headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ key) }

	print(endpoint)
	print(key)
	print(headers)

	def query(payload):
		print(payload)
		response = requests.post(endpoint, headers=headers, json=payload)
		return response.json()
		
	output = query({
		"messages": [{
			"role": "user", 
			"content": question
			}],
		"max_tokens": 500
		})
	
	answer = output["choices"][0]["message"]["content"]
	return "{ \"question\" : \" " + question + "\" , \"answer\" : \" " + answer + " \"}"

def call_default_endpoint(): 
	return "{ \"question\" : \"What is capital of France?\" , \"answer\" : \"Paris\"}"

# %%
def call_external_endpoints(question: str, model_type: str) -> str:

    if (model_type == "tiny_llama"): 
        output = call_tiny_llama_endpoint(question)
    else:
        output = call_default_endpoint(question)
    
    print(output)    

    with Path.open("outputs.jsonl", "w") as f:
        f.write(output)

    return output

# %%
output = call_external_endpoints("What is the capital of France?", "tiny_llama")

# %%
from promptflow.evals.evaluators import (
    ContentSafetyEvaluator,
)
from promptflow.evals.evaluate import evaluate

content_safety_evaluator = ContentSafetyEvaluator(project_scope=azure_ai_project)

json_line_as_json = json.loads(output)
print(json_line_as_json)


content_safety_eval_result = content_safety_evaluator(
    question=json_line_as_json["question"], answer=json_line_as_json["answer"]
)

# %%
# calling Eval API using output file

results = evaluate(
    azure_ai_project=azure_ai_project,
    data="outputs.jsonl", 
    evaluators = {
        "content_safety": content_safety_evaluator
        })

results
# Out:
# [2024-07-23 14:34:33 -0700][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-07-23 14:34:33 -0700][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run promptflow_evals_evaluators_content_safety_content_safety_contentsafetyevaluator_35gl9qag_20240723_143431_963684, log path: /Users/waqasjaved02/.promptflow/.runs/promptflow_evals_evaluators_content_safety_content_safety_contentsafetyevaluator_35gl9qag_20240723_143431_963684/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=promptflow_evals_evaluators_content_safety_content_safety_contentsafetyevaluator_35gl9qag_20240723_143431_963684
# You can view the traces in azure portal since trace destination is set to: azureml://subscriptions/2d385bf4-0756-4a76-aa95-28bf9ed3b625/resourceGroups/rg-wjphihub/providers/Microsoft.MachineLearningServices/workspaces/waqasjaved-5368. The link will be printed once the run is finished.
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/aiohttp/connector.py:1025, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#    1022     async with ceil_timeout(
#    1023         timeout.sock_connect, ceil_threshold=timeout.ceil_threshold
#    1024     ):
# -> 1025         return await self._loop.create_connection(*args, **kwargs)
#    1026 except cert_errors as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py:1149, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1146         raise ValueError(
#    1147             f'A Stream Socket was expected, got {sock!r}')
# -> 1149 transport, protocol = await self._create_connection_transport(
#    1150     sock, protocol_factory, ssl, server_hostname,
#    1151     ssl_handshake_timeout=ssl_handshake_timeout,
#    1152     ssl_shutdown_timeout=ssl_shutdown_timeout)
#    1153 if self._debug:
#    1154     # Get the socket from the transport because SSL transport closes
#    1155     # the old socket and creates a new SSL socket
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py:1182, in BaseEventLoop._create_connection_transport(self, sock, protocol_factory, ssl, server_hostname, server_side, ssl_handshake_timeout, ssl_shutdown_timeout)
#    1181 try:
# -> 1182     await waiter
#    1183 except:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/sslproto.py:578, in SSLProtocol._on_handshake_complete(self, handshake_exc)
#     577 else:
# --> 578     raise handshake_exc
#     580 peercert = sslobj.getpeercert()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/sslproto.py:560, in SSLProtocol._do_handshake(self)
#     559 try:
# --> 560     self._sslobj.do_handshake()
#     561 except SSLAgainErrors:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:917, in SSLObject.do_handshake(self)
#     916 """Start the SSL/TLS handshake."""
# --> 917 self._sslobj.do_handshake()
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorCertificateError           Traceback (most recent call last)
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/transport/_aiohttp.py:303, in AioHttpTransport.send(self, request, stream, proxies, **config)
#     302 socket_timeout = aiohttp.ClientTimeout(sock_connect=timeout, sock_read=read_timeout)
# --> 303 result = await self.session.request(  # type: ignore
#     304     request.method,
#     305     request.url,
#     306     headers=request.headers,
#     307     data=self._get_request_data(request),
#     308     timeout=socket_timeout,
#     309     allow_redirects=False,
#     310     proxy=proxy,
#     311     **config,
#     312 )
#     313 if _is_rest(request):
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/aiohttp/client.py:581, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     580         assert self._connector is not None
# --> 581         conn = await self._connector.connect(
#     582             req, traces=traces, timeout=real_timeout
#     583         )
#     584 except asyncio.TimeoutError as exc:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/aiohttp/connector.py:544, in BaseConnector.connect(self, req, traces, timeout)
#     543 try:
# --> 544     proto = await self._create_connection(req, traces, timeout)
#     545     if self._closed:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/aiohttp/connector.py:944, in TCPConnector._create_connection(self, req, traces, timeout)
#     943 else:
# --> 944     _, proto = await self._create_direct_connection(req, traces, timeout)
#     946 return proto
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/aiohttp/connector.py:1257, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1256 assert last_exc is not None
# -> 1257 raise last_exc
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/aiohttp/connector.py:1226, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1225 try:
# -> 1226     transp, proto = await self._wrap_create_connection(
#    1227         self._factory,
#    1228         host,
#    1229         port,
#    1230         timeout=timeout,
#    1231         ssl=sslcontext,
#    1232         family=hinfo["family"],
#    1233         proto=hinfo["proto"],
#    1234         flags=hinfo["flags"],
#    1235         server_hostname=server_hostname,
#    1236         local_addr=self._local_addr,
#    1237         req=req,
#    1238         client_error=client_error,
#    1239     )
#    1240 except ClientConnectorError as exc:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/aiohttp/connector.py:1027, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#    1026 except cert_errors as exc:
# -> 1027     raise ClientConnectorCertificateError(req.connection_key, exc) from exc
#    1028 except ssl_errors as exc:
#
# ClientConnectorCertificateError: Cannot connect to host stwjphihub876397172926.blob.core.windows.net:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')]
#
# The above exception was the direct cause of the following exception:
#
# ServiceRequestError                       Traceback (most recent call last)
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_async_run_uploader.py:153, in AsyncRunUploader.upload(self, run)
#     143 tasks = [
#     144     # put async functions in tasks to run in coroutines
#     145     self._upload_flow_artifacts(),
#    (...)
#     151     self._upload_instance_results(),
#     152 ]
# --> 153 results = await asyncio.gather(*tasks)
#     155 # merge the results to be a dict
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_async_run_uploader.py:281, in AsyncRunUploader._upload_flow_logs(self)
#     280 remote_folder = f"{Local2Cloud.BLOB_ROOT_PROMPTFLOW}/{Local2Cloud.BLOB_ARTIFACTS}/{self.run.name}"
# --> 281 await self._upload_local_folder_to_blob(local_folder, remote_folder)
#     282 return f"{remote_folder}/{LocalStorageFilenames.FLOW_LOGS_FOLDER}"
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_async_run_uploader.py:406, in AsyncRunUploader._upload_local_folder_to_blob(self, local_folder, remote_folder)
#     404         tasks.append(self._upload_local_file_to_blob(file, blob_path))
# --> 406 await asyncio.gather(*tasks)
#     408 # return the remote folder path
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_async_run_uploader.py:427, in AsyncRunUploader._upload_local_file_to_blob(self, local_file, remote_file, target_datastore)
#     426 # Upload the file to the blob
# --> 427 await self._upload_single_blob(blob_client, local_file, target_datastore)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_async_run_uploader.py:439, in AsyncRunUploader._upload_single_blob(self, blob_client, data_path, target_datastore)
#     438 try:
# --> 439     await blob_client.upload_blob(f, overwrite=self.overwrite)
#     440 except ResourceExistsError as e:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator_async.py:94, in distributed_trace_async.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      93 if span_impl_type is None:
# ---> 94     return await func(*args, **kwargs)
#      96 # Merge span is parameter is set, but only if no explicit parent are passed
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/storage/blob/aio/_blob_client_async.py:421, in BlobClient.upload_blob(self, data, blob_type, length, metadata, **kwargs)
#     420 if blob_type == BlobType.BlockBlob:
# --> 421     return await upload_block_blob(**options)
#     422 if blob_type == BlobType.PageBlob:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/storage/blob/aio/_upload_helpers.py:80, in upload_block_blob(client, stream, length, overwrite, headers, validate_content, max_concurrency, blob_settings, encryption_options, **kwargs)
#      78     headers['x-ms-meta-encryptiondata'] = encryption_data
# ---> 80 response = await client.upload(
#      81     body=data,
#      82     content_length=adjusted_count,
#      83     blob_http_headers=blob_headers,
#      84     headers=headers,
#      85     cls=return_response_headers,
#      86     validate_content=validate_content,
#      87     data_stream_total=adjusted_count,
#      88     upload_stream_current=0,
#      89     tier=tier.value if tier else None,
#      90     blob_tags_string=blob_tags_string,
#      91     immutability_policy_expiry=immutability_policy_expiry,
#      92     immutability_policy_mode=immutability_policy_mode,
#      93     legal_hold=legal_hold,
#      94     **kwargs)
#      96 if progress_hook:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator_async.py:94, in distributed_trace_async.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      93 if span_impl_type is None:
# ---> 94     return await func(*args, **kwargs)
#      96 # Merge span is parameter is set, but only if no explicit parent are passed
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/storage/blob/_generated/aio/operations/_block_blob_operations.py:243, in BlockBlobOperations.upload(self, content_length, body, timeout, transactional_content_md5, metadata, tier, request_id_parameter, blob_tags_string, immutability_policy_expiry, immutability_policy_mode, legal_hold, transactional_content_crc64, blob_http_headers, lease_access_conditions, cpk_info, cpk_scope_info, modified_access_conditions, **kwargs)
#     242 _stream = False
# --> 243 pipeline_response: PipelineResponse = await self._client._pipeline.run(  # pylint: disable=protected-access
#     244     _request, stream=_stream, **kwargs
#     245 )
#     247 response = pipeline_response.http_response
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:219, in AsyncPipeline.run(self, request, **kwargs)
#     218 first_node = self._impl_policies[0] if self._impl_policies else _AsyncTransportRunner(self._transport)
# --> 219 return await first_node.send(pipeline_request)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:68, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      67 try:
# ---> 68     response = await self.next.send(request)
#      69 except Exception:  # pylint: disable=broad-except
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:68, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      67 try:
# ---> 68     response = await self.next.send(request)
#      69 except Exception:  # pylint: disable=broad-except
#
#     [... skipping similar frames: _SansIOAsyncHTTPPolicyRunner.send at line 68 (4 times)]
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:68, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      67 try:
# ---> 68     response = await self.next.send(request)
#      69 except Exception:  # pylint: disable=broad-except
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_redirect_async.py:73, in AsyncRedirectPolicy.send(self, request)
#      72 while redirects_remaining:
# ---> 73     response = await self.next.send(request)
#      74     redirect_location = self.get_redirect_location(response)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:68, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      67 try:
# ---> 68     response = await self.next.send(request)
#      69 except Exception:  # pylint: disable=broad-except
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/storage/blob/_shared/policies_async.py:140, in AsyncStorageRetryPolicy.send(self, request)
#     139             continue
# --> 140         raise err
#     141 if retry_settings['history']:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/storage/blob/_shared/policies_async.py:114, in AsyncStorageRetryPolicy.send(self, request)
#     113 try:
# --> 114     response = await self.next.send(request)
#     115     if is_retry(response, retry_settings['mode']):
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:68, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      67 try:
# ---> 68     response = await self.next.send(request)
#      69 except Exception:  # pylint: disable=broad-except
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/storage/blob/_shared/policies_async.py:66, in AsyncStorageResponseHook.send(self, request)
#      63 response_callback = request.context.get('response_callback') or \
#      64     request.context.options.pop('raw_response_hook', self._response_callback)
# ---> 66 response = await self.next.send(request)
#      67 await response.http_response.load_body()
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:68, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      67 try:
# ---> 68     response = await self.next.send(request)
#      69 except Exception:  # pylint: disable=broad-except
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:68, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      67 try:
# ---> 68     response = await self.next.send(request)
#      69 except Exception:  # pylint: disable=broad-except
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:104, in _AsyncTransportRunner.send(self, request)
#     101 cleanup_kwargs_for_transport(request.context.options)
#     102 return PipelineResponse(
#     103     request.http_request,
# --> 104     await self._sender.send(request.http_request, **request.context.options),
#     105     request.context,
#     106 )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/storage/blob/_shared/base_client_async.py:268, in AsyncTransportWrapper.send(self, request, **kwargs)
#     267 async def send(self, request, **kwargs):
# --> 268     return await self._transport.send(request, **kwargs)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/azure/core/pipeline/transport/_aiohttp.py:348, in AioHttpTransport.send(self, request, stream, proxies, **config)
#     347 except aiohttp.client_exceptions.ClientError as err:
# --> 348     raise ServiceRequestError(err, error=err) from err
#     349 return response
#
# ServiceRequestError: Cannot connect to host stwjphihub876397172926.blob.core.windows.net:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')]
#
# The above exception was the direct cause of the following exception:
#
# UploadInternalError                       Traceback (most recent call last)
# Cell In[18], line 3
#       1 # calling Eval API using output file
# ----> 3 results = evaluate(
#       4     azure_ai_project=azure_ai_project,
#       5     data="outputs.jsonl",
#       6     evaluators = {
#       7         "content_safety": content_safety_evaluator
#       8         })
#      10 results
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_telemetry/__init__.py:111, in log_evaluate_activity.<locals>.wrapper(*args, **kwargs)
#     103 custom_dimensions = {
#     104     "track_in_cloud": track_in_cloud,
#     105     "evaluate_target": evaluate_target,
#     106     "evaluator_config": evaluator_config,
#     107 }
#     109 with log_activity(get_telemetry_logger(), "pf.evals.evaluate", activity_type=ActivityType.PUBLICAPI,
#     110                   user_agent=USER_AGENT, custom_dimensions=custom_dimensions):
# --> 111     result = func(*args, **kwargs)
#     113     try:
#     114         evaluators_info = []
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:365, in evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     357     error_message = (
#     358         "The evaluation failed due to an error during multiprocess bootstrapping."
#     359         "Please ensure the evaluate API is properly guarded with the '__main__' block:\n\n"
#     360         "    if __name__ == '__main__':\n"
#     361         "        evaluate(...)"
#     362     )
#     363     raise RuntimeError(error_message)
# --> 365 raise e
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:340, in evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     272 """Evaluates target or data with built-in or custom evaluators. If both target and data are provided,
#     273     data will be run through target function and then results will be evaluated.
#     274
#    (...)
#     337
#     338 """
#     339 try:
# --> 340     return _evaluate(
#     341         evaluation_name=evaluation_name,
#     342         target=target,
#     343         data=data,
#     344         evaluators=evaluators,
#     345         evaluator_config=evaluator_config,
#     346         azure_ai_project=azure_ai_project,
#     347         output_path=output_path,
#     348         **kwargs,
#     349     )
#     350 except Exception as e:
#     351     # Handle multiprocess bootstrap error
#     352     bootstrap_error = (
#     353         "An attempt has been made to start a new process before the\n        "
#     354         "current process has finished its bootstrapping phase."
#     355     )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:447, in _evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     445     # get_details needs to be called within BatchRunContext scope in order to have user agent populated
#     446     for evaluator_name, evaluator_info in evaluators_info.items():
# --> 447         evaluator_info["result"] = batch_run_client.get_details(evaluator_info["run"], all_results=True)
#     448         evaluator_info["metrics"] = batch_run_client.get_metrics(evaluator_info["run"])
#     450 # Concatenate all results
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_batch_run_client/proxy_client.py:33, in ProxyClient.get_details(self, proxy_run, all_results)
#      32 def get_details(self, proxy_run, all_results=False):
# ---> 33     run = proxy_run.run.result(timeout=BATCH_RUN_TIMEOUT)
#      34     result_df = self._pf_client.get_details(run, all_results=all_results)
#      35     result_df.replace("(Failed)", np.nan, inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/_sdk/_pf_client.py:301, in PFClient.run(self, flow, data, run, column_mapping, variant, connections, environment_variables, name, display_name, tags, resume_from, code, init, **kwargs)
#     228 def run(
#     229     self,
#     230     flow: Union[str, PathLike, Callable] = None,
#    (...)
#     244     **kwargs,
#     245 ) -> Run:
#     246     """Run flow against provided data or run.
#     247
#     248     .. note::
#    (...)
#     299     :rtype: ~promptflow.entities.Run
#     300     """
# --> 301     return self._run(
#     302         flow=flow,
#     303         data=data,
#     304         run=run,
#     305         column_mapping=column_mapping,
#     306         variant=variant,
#     307         connections=connections,
#     308         environment_variables=environment_variables,
#     309         name=name,
#     310         display_name=display_name,
#     311         tags=tags,
#     312         resume_from=resume_from,
#     313         code=code,
#     314         init=init,
#     315         **kwargs,
#     316     )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/_sdk/_pf_client.py:226, in PFClient._run(self, flow, data, run, column_mapping, variant, connections, environment_variables, properties, name, display_name, tags, resume_from, code, init, **kwargs)
#     209         variant, connections = None, None
#     210 run = Run(
#     211     name=name,
#     212     display_name=display_name,
#    (...)
#     224     dynamic_callable=dynamic_callable,
#     225 )
# --> 226 return self.runs.create_or_update(run=run, **kwargs)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/_sdk/_telemetry/activity.py:265, in monitor_operation.<locals>.monitor.<locals>.wrapper(self, *args, **kwargs)
#     263     thread = threading.Thread(target=check_latest_version, daemon=True)
#     264     thread.start()
# --> 265 return f(self, *args, **kwargs)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/_sdk/operations/_run_operations.py:135, in RunOperations.create_or_update(self, run, **kwargs)
#     132 try:
#     133     from promptflow._sdk._orchestrator import RunSubmitter
# --> 135     created_run = RunSubmitter(client=self._client).submit(run=run, **kwargs)
#     136     if stream:
#     137         self.stream(created_run)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/_sdk/_orchestrator/run_submitter.py:58, in RunSubmitter.submit(self, run, stream, **kwargs)
#      56 logger.info(f"Uploading run {run.name!r} to cloud...")
#      57 uploader, pfazure_client = task_results[1]
# ---> 58 portal_url = pfazure_client.runs._upload(run=run, run_uploader=uploader)
#      59 logger.info(f"Updating run {run.name!r} portal url to {portal_url!r}.")
#      60 if portal_url is not None:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_run_operations.py:963, in RunOperations._upload(self, run, run_uploader)
#     960     run_uploader = AsyncRunUploader._from_run_operations(run_ops=self)
#     962 # upload local run details to cloud
# --> 963 result_dict = async_run_allowing_running_loop(run_uploader.upload, run=run)
#     964 run = run_uploader.run
#     965 # patch details about the uploaded run
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/_utils/async_utils.py:96, in async_run_allowing_running_loop(async_func, *args, **kwargs)
#      94         return executor.submit(lambda: asyncio.run(async_func(*args, **kwargs))).result()
#      95 else:
# ---> 96     return asyncio.run(_invoke_async_with_sigint_handler(async_func, *args, **kwargs))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/runners.py:194, in run(main, debug, loop_factory)
#     190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 194     return runner.run(main)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/runners.py:118, in Runner.run(self, coro, context)
#     116 self._interrupt_count = 0
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#     120     if self._interrupt_count > 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py:687, in BaseEventLoop.run_until_complete(self, future)
#     684 if not future.done():
#     685     raise RuntimeError('Event loop stopped before Future completed.')
# --> 687 return future.result()
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/_utils/async_utils.py:65, in _invoke_async_with_sigint_handler(async_func, *args, **kwargs)
#      59 # For the scenario that we don't need to update sigint, just return.
#      60 # The scenarios include:
#      61 # For python >= 3.11, asyncio.run already updated the sigint for cancelling tasks.
#      62 # The user already has his own customized sigint.
#      63 # The current code is not in main thread.
#      64 if not _should_update_sigint():
# ---> 65     return await async_func(*args, **kwargs)
#      66 try:
#      67     loop = asyncio.get_running_loop()
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_async_run_uploader.py:170, in AsyncRunUploader.upload(self, run)
#     168     raise
#     169 except Exception as e:
# --> 170     raise UploadInternalError(f"{error_msg_prefix}. Error: {e}") from e
#
# UploadInternalError: Failed to upload run 'promptflow_evals_evaluators_content_safety_content_safety_contentsafetyevaluator_35gl9qag_20240723_143431_963684'. Error: Cannot connect to host stwjphihub876397172926.blob.core.windows.net:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')]

# %%
df = pd.read_json("testdata/outputs.jsonl", lines=True)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = pd.read_json("testdata/outputs.jsonl", lines=True)
#       2 print(df.head())
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1023, in JsonReader.read(self)
#    1021         data = ensure_str(self.data)
#    1022         data_lines = data.split("\n")
# -> 1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
#    1025     obj = self._get_object_parser(self.data)
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1403, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
#    1402     self.obj = DataFrame(
# -> 1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# ValueError: Unexpected character found when decoding 'true'

# %%
results = evaluate(
    azure_ai_project=azure_ai_project,
    evaluation_name="tiny_llama",
    data="testdata/data.jsonl", 
    target=call_external_endpoints,
    evaluators = {
        "content_safety": content_safety_evaluator
        })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:115, in _validate_and_load_data(target, data, evaluators, output_path, azure_ai_project, evaluation_name)
#     114 try:
# --> 115     initial_data_df = pd.read_json(data, lines=True)
#     116 except Exception as e:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     814 else:
# --> 815     return json_reader.read()
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1023, in JsonReader.read(self)
#    1022         data_lines = data.split("\n")
# -> 1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:1403, in FrameParser._parse(self)
#    1401 if orient == "columns":
#    1402     self.obj = DataFrame(
# -> 1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#
# ValueError: Unexpected character found when decoding 'true'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 results = evaluate(
#       2     azure_ai_project=azure_ai_project,
#       3     evaluation_name="tiny_llama",
#       4     data="testdata/data.jsonl",
#       5     target=call_external_endpoints,
#       6     evaluators = {
#       7         "content_safety": content_safety_evaluator
#       8         })
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_telemetry/__init__.py:111, in log_evaluate_activity.<locals>.wrapper(*args, **kwargs)
#     103 custom_dimensions = {
#     104     "track_in_cloud": track_in_cloud,
#     105     "evaluate_target": evaluate_target,
#     106     "evaluator_config": evaluator_config,
#     107 }
#     109 with log_activity(get_telemetry_logger(), "pf.evals.evaluate", activity_type=ActivityType.PUBLICAPI,
#     110                   user_agent=USER_AGENT, custom_dimensions=custom_dimensions):
# --> 111     result = func(*args, **kwargs)
#     113     try:
#     114         evaluators_info = []
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:365, in evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     357     error_message = (
#     358         "The evaluation failed due to an error during multiprocess bootstrapping."
#     359         "Please ensure the evaluate API is properly guarded with the '__main__' block:\n\n"
#     360         "    if __name__ == '__main__':\n"
#     361         "        evaluate(...)"
#     362     )
#     363     raise RuntimeError(error_message)
# --> 365 raise e
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:340, in evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     272 """Evaluates target or data with built-in or custom evaluators. If both target and data are provided,
#     273     data will be run through target function and then results will be evaluated.
#     274
#    (...)
#     337
#     338 """
#     339 try:
# --> 340     return _evaluate(
#     341         evaluation_name=evaluation_name,
#     342         target=target,
#     343         data=data,
#     344         evaluators=evaluators,
#     345         evaluator_config=evaluator_config,
#     346         azure_ai_project=azure_ai_project,
#     347         output_path=output_path,
#     348         **kwargs,
#     349     )
#     350 except Exception as e:
#     351     # Handle multiprocess bootstrap error
#     352     bootstrap_error = (
#     353         "An attempt has been made to start a new process before the\n        "
#     354         "current process has finished its bootstrapping phase."
#     355     )
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:380, in _evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     368 def _evaluate(
#     369     *,
#     370     evaluation_name: Optional[str] = None,
#    (...)
#     377     **kwargs,
#     378 ):
# --> 380     input_data_df = _validate_and_load_data(target, data, evaluators, output_path, azure_ai_project, evaluation_name)
#     382     # Process evaluator config to replace ${target.} with ${data.}
#     383     if evaluator_config is None:
#
# File ~/dev/azureai-samples/.venv/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:117, in _validate_and_load_data(target, data, evaluators, output_path, azure_ai_project, evaluation_name)
#     115     initial_data_df = pd.read_json(data, lines=True)
#     116 except Exception as e:
# --> 117     raise ValueError(f"Failed to load data from {data}. Please validate it is a valid jsonl data. Error: {str(e)}.")
#     119 return initial_data_df
#
# ValueError: Failed to load data from testdata/data.jsonl. Please validate it is a valid jsonl data. Error: Unexpected character found when decoding 'true'.
